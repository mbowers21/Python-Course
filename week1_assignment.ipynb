# %% [markdown]
# # 🎵 Week 1 Assignment — Music Library Manager
#
# **Course:** Python Programming — Five-Week Foundations
# **Week:** 1 — Variables, Lists, Sets, Dictionaries, Loops, Conditionals, Functions
# **Estimated time:** 2–3 hours
# **Total points:** 100
#
# ---
#
# ## Scenario
#
# A friend has asked you to write a Python script that organizes their music collection. They want to track songs, know which genres they own, find shared tracks between collections, and see a quick summary of their library.
#
# You'll build this step by step across six tasks — each one adding to the same program.
#
# **How to use this notebook:**
# - Read the instructions in each Markdown cell
# - Write your code in the code cell below each task
# - Run your code with **Shift+Return** to see the output
# - Do not modify any cell marked `# DO NOT EDIT`
#
# ---

# %% [markdown]
# ## Task 1 — Set Up the Library Data
# **15 points**
#
# Create the core data structures that will hold your music collection. Use the correct Python type for each kind of data.
#
# **Requirements:**
# 1. Create a variable `library_name` (string) with your friend's name, and `year_created` (integer) for when the library was started.
# 2. Create a **list** called `songs` containing at least 8 song titles as strings.
# 3. Create a **set** called `genres` containing at least 4 genre strings (e.g. `"Rock"`, `"Jazz"`).
#    Use a set because genres should not repeat.
# 4. Create a **dictionary** called `album` with these keys: `"title"`, `"artist"`, `"year"`, `"track_count"`.
# 5. Print all four data structures using f-strings.
#
# > 💡 **Hint:** `genres = {"Rock", "Jazz", "Pop"}` — curly braces with no colons makes a set, not a dict.

# %%
# Task 1 — Set up the library data
# Write your code below. Run with Shift+Return.

# 1. Basic variables
library_name = "Will P's Library"
year_created = 2025

# 2. List of songs (at least 8)
songs = ["Sister Golden Hair", "Kilby Girl", "Get Along", "Redrum", "Dreams", "Iris", "Wagon Wheel", "one of wun"]

# 3. Set of genres (at least 4) — use curly braces {}
genres = {"Yacht Rock", "Alternative Rock", "Country", "Rap"}

# 4. Dictionary for one album
album = {"Title": "Rumours", "Artist": "Fleetwood Mac", "Year": 1977, "Track Count": 11}

# 5. Print everything using f-strings
print(f"Library: {library_name} (created {year_created})")
print(f"Songs: {songs}")
print(f"Genres: {genres}")
print(f"Album: {album}")
# Out:
# Library: Will P's Library (created 2025)
# Songs: ['Sister Golden Hair', 'Kilby Girl', 'Get Along', 'Redrum', 'Dreams', 'Iris', 'Wagon Wheel', 'one of wun']
# Genres: {'Alternative Rock', 'Country', 'Rap', 'Yacht Rock'}
# Album: {'Title': 'Rumours', 'Artist': 'Fleetwood Mac', 'Year': 1977, 'Track Count': 11}

# %% [markdown]
# ---
# ## Task 2 — Modify and Explore the Collection
# **15 points**
#
# Practice adding, removing, and accessing items across all three collection types.
#
# ### How `.add()` works for sets
#
# Sets have their own method for adding items: `.add()`. Unlike lists which use `.append()`, sets use `.add()` because sets are unordered and don't allow duplicates.
#
# ```python
# genres = {"Rock", "Jazz", "Pop"}
#
# genres.add("Folk")       # Adds "Folk" — genres now has 4 items
# genres.add("Rock")       # Rock already exists — nothing changes, no error
# genres.remove("Pop")     # Removes "Pop" from the set
#
# print(genres)            # {"Rock", "Jazz", "Folk"}
# print(len(genres))       # 3
# ```
#
# The key difference from lists:
# - `my_list.append("item")` — always adds to the end of the list
# - `my_set.add("item")` — adds only if the item isn't already there
#
# ---
#
# ### List slicing
#
# Slicing lets you pull out a portion of a list using the syntax `list[start:stop]`. Python returns every item from `start` up to — but **not including** — `stop`.
#
# ```python
# songs = ["A", "B", "C", "D", "E", "F", "G"]
# #index:   0    1    2    3    4    5    6
# ```
#
# | Expression | Result | What it means |
# |------------|--------|---------------|
# | `songs[0]` | `"A"` | First item (index 0) |
# | `songs[2]` | `"C"` | Item at index 2 |
# | `songs[-1]` | `"G"` | Last item (negative counts from the end) |
# | `songs[-2]` | `"F"` | Second-to-last item |
# | `songs[1:4]` | `["B", "C", "D"]` | Index 1 up to (not including) 4 |
# | `songs[0:3]` | `["A", "B", "C"]` | First three items |
# | `songs[4:]` | `["E", "F", "G"]` | From index 4 to the end |
# | `songs[:3]` | `["A", "B", "C"]` | From the beginning up to index 3 |
#
# ```python
# songs = ["Bohemian Rhapsody", "Hotel California", "Wonderwall",
#          "Smells Like Teen Spirit", "Billie Jean", "Rolling in the Deep"]
#
# print(songs[0])      # Bohemian Rhapsody  (first)
# print(songs[-1])     # Rolling in the Deep  (last)
# print(songs[1:4])    # ["Hotel California", "Wonderwall", "Smells Like Teen Spirit"]
# print(songs[:3])     # first three songs
# print(songs[3:])     # everything from index 3 onward
# ```
#
# > 💡 A helpful way to remember: `songs[start:stop]` — `start` is **included**, `stop` is **excluded**.
#
# ---
#
# **Requirements:**
# 1. Add 2 new songs to `songs` using `.append()`. Remove one song by name using `.remove()`.
# 2. Print the **first** song, the **last** song, and a **slice** of the middle three songs.
# 3. Add a new genre to `genres` using `.add()`. Then try adding a genre that already exists — notice that the set doesn't change.
# 4. Add a new key `"label"` to the `album` dictionary. Update the `"year"` value to a different year.
# 5. Print the total number of songs using `len()`.

# %%
# Task 2 — Modify and explore the collection

# 1. Add two songs, remove one
songs.append("Rein Me In")
songs.append("Love Story")
songs.remove("Love Story")

# 2. Print first, last, and middle slice
print(f"First song:  {songs[0]}")
print(f"Last song:   {songs[-1]}")
print(f"Middle three: {songs[2:5]}")

# 3. Add a new genre, then try adding a duplicate
genres.add("Pop")
genres.add("Yacht Rock")
print(f"Genres after additions: {genres}")

# 4. Add 'label' key and update 'year' in album
album = {"Title": "Rumours", "Artist": "Fleetwood Mac", "Year": 1977, "Track Count": 11, "Label": "Warner Bros."}
Year = 1975
print(f"Updated album: {album}")

# 5. Print total number of songs
print(f"Total songs: {len(songs)}")
# Out:
# First song:  Sister Golden Hair
# Last song:   Rein Me In
# Middle three: ['Get Along', 'Redrum', 'Dreams']
# Genres after additions: {'Rap', 'Country', 'Alternative Rock', 'Yacht Rock', 'Pop'}
# Updated album: {'Title': 'Rumours', 'Artist': 'Fleetwood Mac', 'Year': 1977, 'Track Count': 11, 'Label': 'Warner Bros.'}
# Total songs: 9

# %% [markdown]
# ---
# ## Task 3 — Loop Through and Display the Library
# **20 points**
#
# Use loops to neatly print every song, every genre, and every album field.
#
# ### Numbered loops with `range()`
#
# To print a numbered list, use `range(len(...))` to generate the index, then add 1 when printing so the count starts at 1:
#
# ```python
# songs = ["Bohemian Rhapsody", "Hotel California", "Wonderwall"]
#
# for i in range(len(songs)):
#     print(f"{i + 1}. {songs[i]}")
#
# # Output:
# # 1. Bohemian Rhapsody
# # 2. Hotel California
# # 3. Wonderwall
# ```
#
# `range(len(songs))` produces `0, 1, 2` — the valid index positions. Adding 1 in the print statement shifts the display number to start at 1.
#
# ### Adding special characters like ♪
#
# You can paste the ♪ symbol directly into a string — copy it from here and use it inside quotes:
#
# ```python
# print("♪ Bohemian Rhapsody")
# ```
#
# Or use its Unicode escape code, which works on any system:
#
# ```python
# print("\u266a Bohemian Rhapsody")   # \u266a is the Unicode for ♪
# ```
#
# **Requirements:**
# 1. Use `range(len(songs))` in a `for` loop to print every song as a **numbered list starting at 1**.
# 2. Use a `for` loop to print each genre on its own line, with a `♪` prefix.
# 3. Use a `for` loop to iterate over `album.items()` and print each key and value on its own line.
# 4. Use a `while` loop to **count down** from the total number of songs to 1, then print `"Countdown complete!"`.
#
# > 💡 **Hint:** Inside the loop, `songs[i]` accesses the song at position `i`. Remember `i + 1` in your `print()` to show 1-based numbers.

# %%
# Task 3 — Loops

# 1. Numbered song list using range (displaying 1-based numbers)
print("--- Song List ---")
for i in range(len(songs)):
    print(f"{i + 1}. {songs[i]}")

# 2. Print each genre with a ♪ prefix
print("\n--- Genres ---")
for genre in genres:
    print(f"♪ {genre}")

# 3. Print each album key/value pair using .items()
print("\n--- Album Details ---")
for key, value in album.items():
    print(f"{key}: {value}")

# 4. While loop countdown from len(songs) down to 1
print("\n--- Countdown ---")
i = len(songs)
while i > 0:
    print(i)
    i -= 1

print("Countdown complete!")
# Out:
# --- Song List ---
# 1. Sister Golden Hair
# 2. Kilby Girl
# 3. Get Along
# 4. Redrum
# 5. Dreams
# 6. Iris
# 7. Wagon Wheel
# 8. one of wun
# 9. Rein Me In
#
# --- Genres ---
# ♪ Rap
# ♪ Country
# ♪ Alternative Rock
# ♪ Yacht Rock
# ♪ Pop
#
# --- Album Details ---
# Title: Rumours
# Artist: Fleetwood Mac
# Year: 1977
# Track Count: 11
# Label: Warner Bros.
#
# --- Countdown ---
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# Countdown complete!

# %% [markdown]
# ---
# ## Quick Reference — Set Operators: `in`, `&`, and `|`
#
# Before Task 4, here are three tools you'll use to work with sets.
#
# ### `in` — membership test
#
# `in` checks whether a value exists inside any collection (list, set, or dictionary).
#
# ```python
# genres = {"Rock", "Jazz", "Pop"}
#
# print("Jazz" in genres)    # True  — Jazz is in the set
# print("Metal" in genres)   # False — Metal is not in the set
#
# songs = ["Bohemian Rhapsody", "Hotel California"]
# print("Hotel California" in songs)   # True
# ```
#
# Use `in` inside an `if` statement to make decisions:
#
# ```python
# if "Jazz" in genres:
#     print("This library has Jazz!")
# else:
#     print("No Jazz here.")
# ```
#
# ---
#
# ### `&` — intersection (items in **both** sets)
#
# The `&` operator returns only the items that appear in **both** sets.
#
# ```python
# my_songs      = {"Bohemian Rhapsody", "Hotel California", "Wonderwall"}
# their_songs   = {"Wonderwall", "Smells Like Teen Spirit", "Hotel California"}
#
# shared = my_songs & their_songs
# print(shared)   # {"Wonderwall", "Hotel California"}
# ```
#
# Think of it as: *"what do we have in common?"*
#
# ---
#
# ### `|` — union (all unique items from **either** set)
#
# The `|` operator combines both sets and removes any duplicates.
#
# ```python
# my_songs      = {"Bohemian Rhapsody", "Hotel California", "Wonderwall"}
# their_songs   = {"Wonderwall", "Smells Like Teen Spirit", "Hotel California"}
#
# combined = my_songs | their_songs
# print(combined)
# # {"Bohemian Rhapsody", "Hotel California", "Wonderwall", "Smells Like Teen Spirit"}
# ```
#
# Think of it as: *"everything, with no repeats."*
#
# | Operator | Name | Returns |
# |----------|------|---------|
# | `in` | Membership test | `True` or `False` |
# | `&` | Intersection | Items in **both** sets |
# | `\|` | Union | All unique items from **either** set |

# %% [markdown]
# ---
# ## Task 4 — Classify Songs with Conditionals and Set Operations
# **20 points**
#
# Use `if`/`else` and the set operators from the reference above to apply labels and find overlap between collections.
#
# **Requirements:**
# 1. Create a second set called `favourites` containing 4–5 song titles that **partially overlap** with your `songs` list (some titles the same, some different).
# 2. Convert `songs` to a set called `songs_set`. Use `&` to find songs in **both** `songs_set` and `favourites`. Print the result as `"Favourites in library: ..."`
# 3. Use `|` to find **all unique titles** across both sets. Print the total count.
# 4. Loop over `songs`. For each song, use `if`/`else` to print `"(favourite)"` or `"(not a favourite)"` next to the title.
# 5. Check whether `"Jazz"` is in `genres` using the `in` operator and print an appropriate message.

# %%
# Task 4 — Conditionals and set operations

# 1. Create a favourites set (partially overlapping with songs)
favourites = {"Sister Golden Hair", "Dreams", "Choosin' Texas", "Hotel California"}

# 2. Convert songs list to a set, find the intersection
songs_set = set(songs)
in_both = songs_set & favourites
print(f"Favourites in library: {in_both}")

# 3. Union of both sets — all unique titles
all_titles = songs_set | favourites
print(f"Total unique titles across both collections: {len(all_titles)}")

# 4. Loop over songs and label each one
print("\n--- Song Labels ---")
for song in songs:
    if song in favourites:
        print(f"{song} is a favourite!")
    else:
        print(f"{song} is not a favourite.")

# 5. Check if 'Jazz' is in genres
print("\n--- Genre Check ---")
if "Jazz" in genres:
    print("Jazz is in the genres set.")
else:
    print("Jazz is not in the genres set.")
# Out:
# Favourites in library: {'Sister Golden Hair', 'Dreams'}
# Total unique titles across both collections: 11
#
# --- Song Labels ---
# Sister Golden Hair is a favourite!
# Kilby Girl is not a favourite.
# Get Along is not a favourite.
# Redrum is not a favourite.
# Dreams is a favourite!
# Iris is not a favourite.
# Wagon Wheel is not a favourite.
# one of wun is not a favourite.
# Rein Me In is not a favourite.
#
# --- Genre Check ---
# Jazz is not in the genres set.

# %% [markdown]
# ---
# ## Task 5 — Write Library Functions
# **20 points**
#
# Wrap common operations into reusable functions. Each function should do **one thing** and return a result.
#
# **Requirements:**
# 1. `add_song(songs, title)` — appends `title` to the list and returns the updated list.
# 2. `find_song(songs, title)` — returns `True` if the song is in the list, `False` otherwise.
# 3. `genre_summary(genres)` — returns a string like `"5 genres: Rock, Jazz, Pop, Folk, Soul"`.
# 4. `library_stats(songs, genres, album)` — prints a formatted summary showing library name, song count, genre count, and album title. Does not need to return anything.
# 5. Call all four functions and print their return values.
#
# > 💡 **Hint:** Use `", ".join(genres)` to turn a set into a comma-separated string inside `genre_summary`.

# %%
# Task 5 — Functions

def add_song(songs, title):
    """Adds a song to the list and returns the updated list."""
    # Your code here
    songs.append(title)
    return songs


def find_song(songs, title):
    """Returns True if title is in songs, False otherwise."""
    # Your code here
    if title in songs:
        return True
    else:
        return False


def genre_summary(genres):
    """Returns a string like '4 genres: Rock, Jazz, Pop, Folk'."""
    # Your code here
    return f"{len(genres)} genres: {', '.join(genres)}"


def library_stats(songs, genres, album):
    """Prints a formatted summary of the library."""
    # Your code here
    print("\n=== Library Statistics ===")
    print(f"Library Name: {library_name}")
    print(f"  - Songs: {len(songs)}")
    print(f"  - Genres: {len(genres)}")
    print(f"  - Album: {album}")


# --- Call all four functions below ---

# Test add_song
songs = add_song(songs, "My New Favourite Song")
print(f"After add_song: {songs[-1]}")  # Should print the new title

# Test find_song
print(find_song(songs, "My New Favourite Song"))   # Should print True
print(find_song(songs, "This Song Doesn't Exist")) # Should print False

# Test genre_summary
print(genre_summary(genres))

# Test library_stats
library_stats(songs, genres, album)
# Out:
# After add_song: My New Favourite Song
# True
# False
# 5 genres: Rap, Country, Alternative Rock, Yacht Rock, Pop
#
# === Library Statistics ===
# Library Name: Will P's Library
#   - Songs: 11
#   - Genres: 5
#   - Album: {'Title': 'Rumours', 'Artist': 'Fleetwood Mac', 'Year': 1977, 'Track Count': 11, 'Label': 'Warner Bros.'}

# %% [markdown]
# ---
# ## Task 6 — Commit to GitHub
# **10 points**
#
# Save your finished notebook to your course repository.
#
# **Steps:**
# 1. Save this notebook: **File → Save Notebook** (or `Cmd+S`).
# 2. Move or copy the file into your `week1/` folder inside `python-course/`.
# 3. Open Terminal and run:
#
# ```bash
# cd ~/Documents/python-course
# git add .
# git commit -m "Week 1 assignment: music library notebook"
# git push
# ```
#
# 4. Verify the `.ipynb` file appears in the `week1/` folder on github.com.
#
# > 💡 **Note:** GitHub renders Jupyter notebooks automatically — your instructor can see all your code and output directly in the browser without needing to download anything.
#
# ---
# ## Grading Rubric
#
# | Task | Points | Full marks when… |
# |------|--------|-------------------|
# | 1 — Data setup | 15 | All four types correct; f-strings used for all output |
# | 2 — Modify | 15 | Correct methods used; indexing and slicing work |
# | 3 — Loops | 20 | All four loops work; `enumerate` starts at 1; `dict.items()` used |
# | 4 — Conditionals | 20 | Set intersection and union correct; every song is labelled |
# | 5 — Functions | 20 | All four functions defined, return correct values, and are called |
# | 6 — GitHub | 10 | `.ipynb` file in `week1/` with a descriptive commit message |
# | **Total** | **100** | |
#
# ---
# ## Before You Submit — Checklist
#
# Run through this before pushing to GitHub:
#
# - [ ] All six task cells run without errors (use **Kernel → Restart & Run All** to confirm)
# - [ ] A **set** is used for `genres` — not a list
# - [ ] Set operations (`&` and `|`) are used in Task 4
# - [ ] All four functions are defined **and** called in Task 5
# - [ ] F-strings are used throughout — no `+` string concatenation
# - [ ] Notebook is committed to `week1/` on GitHub

# %%
# Self-check cell — run this last to verify your work
# DO NOT EDIT THIS CELL

print("=" * 40)
print("  Self-check Results")
print("=" * 40)

checks = []

# Check 1: library_name and year_created exist and are the right types
try:
    assert isinstance(library_name, str), "library_name should be a string"
    assert isinstance(year_created, int), "year_created should be an integer"
    checks.append(("library_name and year_created", True, ""))
except Exception as e:
    checks.append(("library_name and year_created", False, str(e)))

# Check 2: songs is a list with at least 8 items
try:
    assert isinstance(songs, list), "songs should be a list"
    assert len(songs) >= 8, f"songs should have at least 8 items (you have {len(songs)})"
    checks.append(("songs list", True, ""))
except Exception as e:
    checks.append(("songs list", False, str(e)))

# Check 3: genres is a set with at least 4 items
try:
    assert isinstance(genres, set), "genres should be a set, not a list or dict"
    assert len(genres) >= 4, f"genres should have at least 4 items (you have {len(genres)})"
    checks.append(("genres set", True, ""))
except Exception as e:
    checks.append(("genres set", False, str(e)))

# Check 4: album is a dict with the required keys
try:
    assert isinstance(album, dict), "album should be a dictionary"
    required_keys = {"title", "artist", "year", "track_count"}
    missing = required_keys - album.keys()
    assert not missing, f"album is missing keys: {missing}"
    checks.append(("album dictionary", True, ""))
except Exception as e:
    checks.append(("album dictionary", False, str(e)))

# Check 5: functions exist and behave correctly
try:
    assert callable(add_song), "add_song is not defined"
    assert callable(find_song), "find_song is not defined"
    assert callable(genre_summary), "genre_summary is not defined"
    assert callable(library_stats), "library_stats is not defined"

    test_list = ["Song A", "Song B"]
    result = add_song(test_list.copy(), "Song C")
    assert "Song C" in result, "add_song should add the title to the list"

    assert find_song(["Song A"], "Song A") == True, "find_song should return True when song exists"
    assert find_song(["Song A"], "Song Z") == False, "find_song should return False when song is missing"

    summary = genre_summary({"Rock", "Jazz"})
    assert isinstance(summary, str), "genre_summary should return a string"
    assert "2" in summary, "genre_summary should include the count"
    checks.append(("functions", True, ""))
except Exception as e:
    checks.append(("functions", False, str(e)))

# Print results
passed = 0
for name, ok, msg in checks:
    icon = "✓" if ok else "✗"
    status = "PASS" if ok else "FAIL"
    print(f"  {icon} {name}: {status}")
    if msg:
        print(f"      → {msg}")
    if ok:
        passed += 1

print("=" * 40)
print(f"  {passed}/{len(checks)} checks passed")
if passed == len(checks):
    print("  Great work — ready to push to GitHub!")
else:
    print("  Fix the issues above and run again.")
print("=" * 40)
